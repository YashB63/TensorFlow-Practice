# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create Features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y)
plt.show()

# %%
# Turn our NumPy array to Tensors with dtype = float32
X = tf.cast(tf.constant(X), dtype=tf.float32)
y = tf.cast(tf.constant(y), dtype=tf.float32)
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
# Let's rebuild our model

# 1. Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(1)
])

# 2. Compile the model 
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# 3. Fit the model (this time we'll train for longer)
model.fit(tf.expand_dims(X, axis= -1),y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 245ms/step - loss: 12.4714 - mae: 12.4714
# Epoch 2/100
# 1/1 [==============================] - 0s 3ms/step - loss: 11.8828 - mae: 11.8828
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 11.2792 - mae: 11.2792
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.6538 - mae: 10.6538
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.0022 - mae: 10.0022
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.3259 - mae: 9.3259
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 8.6182 - mae: 8.6182
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 7.8691 - mae: 7.8691
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0720 - mae: 7.0720
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2162 - mae: 6.2162
# Epoch 11/100
# ...

# %%
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 80ms/step
# array([[31.952057]], dtype=float32)

# %%
# Now in order to improve our model what we can do is add more hidden layers
# Let's rebuild our model

# 1. Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(1)
])

# 2. Compile the model 
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# 3. Fit the model (this time we'll train for longer)
model.fit(tf.expand_dims(X, axis= -1),y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 208ms/step - loss: 13.8736 - mae: 13.8736
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 13.3853 - mae: 13.3853
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 12.9268 - mae: 12.9268
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 12.4597 - mae: 12.4597
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 11.9843 - mae: 11.9843
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 11.4718 - mae: 11.4718
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.9044 - mae: 10.9044
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.2824 - mae: 10.2824
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: 9.5411 - mae: 9.5411
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6846 - mae: 8.6846
# Epoch 11/100
# ...

# %%
model.predict([17.0]) # Now we obtain a better accuracy
# Out:
# 1/1 [==============================] - 0s 50ms/step
# array([[30.809517]], dtype=float32)

# %%
# Let's change the optimizer from Stochastic Gradient Descent to Adam Optimizer
# 1. Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(1)
])

# 2. Compile the model 
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["mae"])

# 3. Fit the model (this time we'll train for longer)
model.fit(tf.expand_dims(X, axis= -1),y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 296ms/step - loss: 13.3220 - mae: 13.3220
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 13.0409 - mae: 13.0409
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 12.7656 - mae: 12.7656
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 12.4917 - mae: 12.4917
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 12.2196 - mae: 12.2196
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 11.9486 - mae: 11.9486
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 11.6886 - mae: 11.6886
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 11.4341 - mae: 11.4341
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.1825 - mae: 11.1825
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 10.9309 - mae: 10.9309
# Epoch 11/100
# ...

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[31.81293]], dtype=float32)
